# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ASK:
#
# Será que é possível indicar cervejas que o usuário vai gostar, sabendo as que ele ja experimentou, assim melhorando sua experiência futura com base em experiências passadas?

# %% [markdown]
# GET:
#
# Para sanar essa dúvida precisamos de dados... Para isso, fomos a busca e encontramos algo interessante

# %% [markdown]
# No kaggle achamos esse conjunto de dados: https://www.kaggle.com/datasets/rdoume/beerreviews?select=beer_reviews.csv
#
# e a partir dele vamos explorar para buscar entender os dados e como eles podem nos ajudar a modelar a nossa solução

# %% [markdown]
# EXPLORE:

# %%
df = pd.read_csv('beer_reviews.csv')

# %%
df
# Out:
#          brewery_id                 brewery_name  review_time  review_overall  \
# 0             10325              Vecchio Birraio   1234817823             1.5
# 1             10325              Vecchio Birraio   1235915097             3.0
# 2             10325              Vecchio Birraio   1235916604             3.0
# 3             10325              Vecchio Birraio   1234725145             3.0
# 4              1075      Caldera Brewing Company   1293735206             4.0
# ...             ...                          ...          ...             ...
# 1586609       14359  The Defiant Brewing Company   1162684892             5.0
# 1586610       14359  The Defiant Brewing Company   1161048566             4.0
# 1586611       14359  The Defiant Brewing Company   1160702513             4.5
# 1586612       14359  The Defiant Brewing Company   1160023044             4.0
# 1586613       14359  The Defiant Brewing Company   1160005319             5.0
#
#          review_aroma  review_appearance review_profilename  \
# 0                 2.0                2.5            stcules
# 1                 2.5                3.0            stcules
# 2                 2.5                3.0            stcules
# 3                 3.0                3.5            stcules
# 4                 4.5                4.0     johnmichaelsen
# ...               ...                ...                ...
# 1586609           4.0                3.5         maddogruss
# 1586610           5.0                2.5          yelterdow
# 1586611           3.5                3.0           TongoRad
# 1586612           4.5                4.5           dherling
# 1586613           4.5                4.5               cbl2
#
#                              beer_style  review_palate  review_taste  \
# 0                            Hefeweizen            1.5           1.5
# 1                    English Strong Ale            3.0           3.0
# 2                Foreign / Export Stout            3.0           3.0
# 3                       German Pilsener            2.5           3.0
# 4        American Double / Imperial IPA            4.0           4.5
# ...                                 ...            ...           ...
# 1586609                     Pumpkin Ale            4.0           4.0
# 1586610                     Pumpkin Ale            2.0           4.0
# 1586611                     Pumpkin Ale            3.5           4.0
# 1586612                     Pumpkin Ale            4.5           4.5
# 1586613                     Pumpkin Ale            4.5           4.5
#
#                       beer_name  beer_abv  beer_beerid
# 0                  Sausa Weizen       5.0        47986
# 1                      Red Moon       6.2        48213
# 2        Black Horse Black Beer       6.5        48215
# 3                    Sausa Pils       5.0        47969
# 4                 Cauldron DIPA       7.7        64883
# ...                         ...       ...          ...
# 1586609      The Horseman's Ale       5.2        33061
# 1586610      The Horseman's Ale       5.2        33061
# 1586611      The Horseman's Ale       5.2        33061
# 1586612      The Horseman's Ale       5.2        33061
# 1586613      The Horseman's Ale       5.2        33061
#
# [1586614 rows x 13 columns]

# %%
df.shape
# Out:
# (1586614, 13)

# %% [markdown]
# Uau, temos aqui mais de um milhão de registros e também 13 'features' que descrevem nossos dados, mas vamos aqui buscar entender o que são esses dados, de que forma são relevantes para nós, e como podemos manipulálos

# %% [markdown]
# Dentro da nossa análise (objetivo de criar um sistema de recomendação), não faz sentido guardarmos dados da cervejaria

# %%
df = df.drop(columns=['brewery_id','brewery_name'],axis=1)

# %% [markdown]
# Será que existem valores nulos?

# %%
nulos_por_coluna = df.isnull().sum()

# Exibir o número de valores nulos por coluna
print("Quantidade de valores nulos por coluna:")
print(nulos_por_coluna)
# Out:
# Quantidade de valores nulos por coluna:
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# review_profilename      348
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_abv              67785
# beer_beerid               0
# dtype: int64

# %% [markdown]
# Temos poucos nulos para um dataset de um milhão e meio. Mas para esses nulos no abv, será que conseguimos preencher, caso o abv de uma dessas cervejas ja tenha sido preenchida?

# %%
valores_abv_por_id = df.dropna(subset=['beer_abv']).set_index('beer_beerid')['beer_abv'].to_dict()

df['beer_abv'] = df.apply(lambda row: valores_abv_por_id.get(row['beer_beerid'], row['beer_abv']), axis=1)

# %%
nulo_abv = df['beer_abv'].isnull().sum()

print(nulo_abv)
# Out:
# 67785

# %% [markdown]
# A resposta é não rs.

# %% [markdown]
# quantas cervejas estão sem essa informação?

# %%
unique_beer_ids_with_null_abv = df[df['beer_abv'].isnull()]['beer_beerid'].nunique()
unique_beer_ids_with_null_abv
# Out:
# 17043

# %% [markdown]
# 17 mil cervejas diferentes, acho que é muito para preencher a mão rs

# %% [markdown]
# Como estamos trabalhando com um sistema de recomendação, o usuário que avaliou é bastante importante para nós. e já que temos muitos dados, iremos excluir as linhas com nulo nesse campo

# %%
df = df.dropna(subset=['review_profilename'])

# %% [markdown]
# Dicionário:
#
#
# Brewery id: é um identificador único atribuído a cada cervejaria listada no conjunto de dados
#
# brewery name: é o nome da cervejaria
#
# Review time: provavelmente se refere ao momento em que uma avaliação ou revisão específica de uma cerveja foi registrada. Porém parece estar codificado.
#
# Review Overall: pontuação geral ou avaliação geral dada a uma cerveja específica por um revisor
#
# Review aroma: Assim como o review overall, é uma coluna subjetiva e trata da nota atribuida ao aroma de cada cerveja.
#
# Review appareance: Subjetiva e trata a respeito da aparência visual
#
# Review profile name: Essa coluna descre o nome de usuario daquele revisor, ou seja para aquela aquela cerveja, com aquelas notas, quem atribuiu.
#
# Beer_Style: categorização do tipo ou estilo específico de cerveja que está sendo avaliada ou descrita. Cada cerveja pode ser classificada em um estilo com base em suas características de sabor, aroma, aparência, ingredientes e outros atributos distintivos. Temos alguns estilos como IPA, PILSEN...
#
# Review taste: pontuação atribuída à sensação na boca de uma cerveja específica por um revisor
#
# Beer name: Nome da cerveja
#
# beer abv: Alcoól por volume
#
# beer id: id de cada cerveja

# %% [markdown]
# Com essa descrição e entendimento é natural que surjam algumas dúvidas. Por exemplo, será que essa coluna de review time realmente pode ser convertida?

# %%
datas = df['review_time']
datas
# Out:
# 0          1234817823
# 1          1235915097
# 2          1235916604
# 3          1234725145
# 4          1293735206
#               ...
# 1586609    1162684892
# 1586610    1161048566
# 1586611    1160702513
# 1586612    1160023044
# 1586613    1160005319
# Name: review_time, Length: 1586266, dtype: int64

# %% [markdown]
# Para isso, após algumas pesquisas vimos que pode estar em padrão unix. E vamos tentar convertê-las

# %%
ndt = []
for data in datas:
    dt_object = datetime.datetime.fromtimestamp(data)
    formatted_date = dt_object.strftime('%Y-%m-%d %H:%M:%S')

    ndt.append(formatted_date)

dt = {'Data review': ndt}
df_dt = pd.DataFrame(dt)

# %%
df_dt
# Out:
#                  Data review
# 0        2009-02-16 17:57:03
# 1        2009-03-01 10:44:57
# 2        2009-03-01 11:10:04
# 3        2009-02-15 16:12:25
# 4        2010-12-30 15:53:26
# ...                      ...
# 1586261  2006-11-04 21:01:32
# 1586262  2006-10-16 22:29:26
# 1586263  2006-10-12 22:21:53
# 1586264  2006-10-05 01:37:24
# 1586265  2006-10-04 20:41:59
#
# [1586266 rows x 1 columns]

# %% [markdown]
# Uau, então realmente é possivél converter aquela coluna em data, mas deixaremos daquele jeito por enquanto

# %%
#Quantas cervejas temos no dataset?

qtd_cervejas = df['beer_beerid'].nunique()
print(qtd_cervejas)
# Out:
# 66051

# %% [markdown]
# Não sabia que existiam tantas cervejas assim rs

# %% [markdown]
# Para as outras colunas de review, sabemos que são subjetivas, mas para cada uma delas, qual será que é o intervalo

# %%
review_colunms = ['review_overall','review_aroma', 'review_appearance', 'review_palate', 'review_taste' ]

# %%
for c in review_colunms:
    print(c, df[c].min(), ' - ',df[c].max())
# Out:
# review_overall 0.0  -  5.0
# review_aroma 1.0  -  5.0
# review_appearance 0.0  -  5.0
# review_palate 1.0  -  5.0
# review_taste 1.0  -  5.0

# %% [markdown]
# Parece que estão estabelecidos valores de 0 a 5 para todas colunas, embora sejam subjetivas, temos intervalos bem definidos

# %% [markdown]
# Como será que essas notas se distribuem para cada review? Será que temos uma distribuição normal das coisas, ou temos a maioria das cervejas proximas de 5 e vice-versa?

# %%
for c in review_colunms:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=df[c], palette="viridis")

    # Adicionar título e rótulos dos eixos
    plt.title(f"Distribuição de Notas {c}")
    plt.xlabel("Notas")
    plt.ylabel("Contagem")

    # Exibir o gráfico
    plt.show()

# %%
for c in review_colunms:
    print(df[c].mean(), df[c].median())
# Out:
# 3.8156280220341356 4.0
# 3.735685565976955 4.0
# 3.84167125816225 4.0
# 3.7437532544982997 4.0
# 3.7929209224682365 4.0

# %% [markdown]
# Vemos aqui, que predominantemente temos os dados 'ao redor' do valor 4.

# %% [markdown]
# Será que mesmo para valores tão proximos, temos a notas baixas como "outliers"?

# %%
for c in review_colunms:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df[c], color='skyblue')

    # Adicionar título e rótulo do eixo x
    plt.title(f"Gráfico de Boxplot de {c}")
    plt.xlabel("Notas")

    # Exibir o gráfico
    plt.show()

# %% [markdown]
# Uau, com esses gráficos conseguimos ver que algumas notas, mesmo que dentro do domínio do problema são consideradas anomalias

# %% [markdown]
# O estilo de cerveja pode nos trazer algumas informações interessantes não contidas no dataset. Vamos analisar

# %%
df['beer_style'].nunique()
# Out:
# 104

# %%
estilos_unicos = df['beer_style'].unique()

# Exibir a lista de estilos de cerveja únicos
for estilo in estilos_unicos:
    print(estilo)
# Out:
# Hefeweizen
# English Strong Ale
# Foreign / Export Stout
# German Pilsener
# American Double / Imperial IPA
# Herbed / Spiced Beer
# Light Lager
# Oatmeal Stout
# American Pale Lager
# Rauchbier
# American Pale Ale (APA)
# American Porter
# Belgian Strong Dark Ale
# American IPA
# American Stout
# Russian Imperial Stout
# American Amber / Red Ale
# American Strong Ale
# Märzen / Oktoberfest
# American Adjunct Lager
# American Blonde Ale
# Euro Pale Lager
# English Brown Ale
# Scotch Ale / Wee Heavy
# Fruit / Vegetable Beer
# American Double / Imperial Stout
# Belgian Pale Ale
# English Bitter
# English Porter
# Irish Dry Stout
# American Barleywine
# Belgian Strong Pale Ale
# Doppelbock
# Maibock / Helles Bock
# Pumpkin Ale
# Dortmunder / Export Lager
# Euro Strong Lager
# Euro Dark Lager
# Low Alcohol Beer
# Weizenbock
# Extra Special / Strong Bitter (ESB)
# Bock
# English India Pale Ale (IPA)
# Altbier
# Kölsch
# Munich Dunkel Lager
# Rye Beer
# American Pale Wheat Ale
# Milk / Sweet Stout
# Schwarzbier
# Vienna Lager
# American Amber / Red Lager
# Scottish Ale
# Witbier
# American Black Ale
# Saison / Farmhouse Ale
# English Barleywine
# English Dark Mild Ale
# California Common / Steam Beer
# Czech Pilsener
# English Pale Ale
# Belgian IPA
# Tripel
# Flanders Oud Bruin
# American Brown Ale
# Winter Warmer
# Smoked Beer
# Dubbel
# Flanders Red Ale
# Dunkelweizen
# Roggenbier
# Keller Bier / Zwickel Bier
# Belgian Dark Ale
# Bière de Garde
# Japanese Rice Lager
# Black & Tan
# Irish Red Ale
# Chile Beer
# English Stout
# Cream Ale
# American Wild Ale
# American Double / Imperial Pilsner
# Scottish Gruit / Ancient Herbed Ale
# Wheatwine
# American Dark Wheat Ale
# American Malt Liquor
# Baltic Porter
# Munich Helles Lager
# Kristalweizen
# English Pale Mild Ale
# Lambic - Fruit
# Old Ale
# Quadrupel (Quad)
# Braggot
# Lambic - Unblended
# Eisbock
# Berliner Weissbier
# Kvass
# Faro
# Gueuze
# Gose
# Happoshu
# Sahti
# Bière de Champagne / Bière Brut

# %% [markdown]
# Vamos carregar um dataset com o estilo e uma taxa de ibu (indicador de amargor)

# %%
estilos = pd.read_csv('saida.csv')
estilos
# Out:
#                           beer_style  ibu_min  ibu_max
# 0                            Altbier     25.0     50.0
# 1                   Amber Kellerbier     25.0     40.0
# 2                 American Amber Ale     25.0     40.0
# 3                American Barleywine     50.0    100.0
# 4                 American Brown Ale     20.0     30.0
# ..                               ...      ...      ...
# 192               Berliner Weissbier      7.0      7.0
# 193                            Kvass     12.0     12.0
# 194                             Faro     10.0     10.0
# 195                         Happoshu     11.0     11.0
# 196  Bière de Champagne / Bière Brut     40.0     40.0
#
# [197 rows x 3 columns]

# %%
valores_df1 = df['beer_style'].unique()

# Obter os valores únicos da coluna 'coluna_igual' no segundo DataFrame
valores_df2 = estilos['beer_style'].unique()

# Identificar quais valores estão em valores_df1 e não estão em valores_df2
valores_nao_em_df2 = [valor for valor in valores_df1 if valor not in valores_df2]
print(len(valores_nao_em_df2))
for valor in valores_nao_em_df2:
    print(valor)
# Out:
# 0

# %% [markdown]
# Bom ressaltar que inicialmente esse número não era 0, foi feito uma coleta de dados para que podessemos saber o ibu de cada cerveja. Agora vamos inserir essas informações no dataset

# %%
df = pd.merge(df, estilos, on='beer_style')

df
# Out:
#          review_time  review_overall  review_aroma  review_appearance  \
# 0         1234817823             1.5           2.0                2.5
# 1         1224350360             4.0           4.0                3.0
# 2         1316545215             4.0           3.5                3.0
# 3         1133896338             3.5           3.5                3.0
# 4         1193191936             4.0           4.0                3.5
# ...              ...             ...           ...                ...
# 1586261   1288562807             4.5           4.0                4.0
# 1586262   1288546131             4.0           4.0                3.5
# 1586263   1281632126             4.0           4.0                5.0
# 1586264   1279650183             5.0           4.0                4.5
# 1586265   1276009569             4.5           5.0                5.0
#
#         review_profilename                       beer_style  review_palate  \
# 0                  stcules                       Hefeweizen            1.5
# 1              Likeburning                       Hefeweizen            4.0
# 2                   JamesS                       Hefeweizen            4.0
# 3                GusterFan                       Hefeweizen            3.0
# 4                 harpo111                       Hefeweizen            3.5
# ...                    ...                              ...            ...
# 1586261          MasterSki  Bière de Champagne / Bière Brut            4.5
# 1586262          jrallen34  Bière de Champagne / Bière Brut            4.5
# 1586263           Phyl21ca  Bière de Champagne / Bière Brut            4.0
# 1586264          wordemupg  Bière de Champagne / Bière Brut            4.5
# 1586265              bobsy  Bière de Champagne / Bière Brut            4.5
#
#          review_taste              beer_name  beer_abv  beer_beerid  ibu_min  \
# 0                 1.5           Sausa Weizen       5.0        47986     10.0
# 1                 3.5             Hefeweizen       5.0        20575     10.0
# 2                 4.5            Hefe Weizen       4.5        73291     10.0
# 3                 3.5          Wheezy Heifer       5.5        27229     10.0
# 4                 3.5            Hefe-Weizen       5.5         2776     10.0
# ...               ...                    ...       ...          ...      ...
# 1586261           4.0  Dominus Vobiscum Brut      11.0        59014     40.0
# 1586262           4.0  Dominus Vobiscum Brut      11.0        59014     40.0
# 1586263           4.0  Dominus Vobiscum Brut      11.0        59014     40.0
# 1586264           4.5  Dominus Vobiscum Brut      11.0        59014     40.0
# 1586265           4.5  Dominus Vobiscum Brut      11.0        59014     40.0
#
#          ibu_max
# 0           15.0
# 1           15.0
# 2           15.0
# 3           15.0
# 4           15.0
# ...          ...
# 1586261     40.0
# 1586262     40.0
# 1586263     40.0
# 1586264     40.0
# 1586265     40.0
#
# [1586266 rows x 13 columns]

# %% [markdown]
# Contudo, não é muito bom trabalharmos com esses intervalos, por isso, vamos trazer como um valor único, sendo a média entre ambos.

# %%
df['mean ibu'] = (df['ibu_min'] + df['ibu_max'])/2

# %%
df = df.drop(columns=['ibu_min', 'ibu_max'],axis=1)

# %% [markdown]
# Será que temos variáveis muito correlacionadas? Ou seja, será que temos variáveis que são explicadas por outras?

# %%
df_c = ['beer_abv','mean ibu']
df_c.extend(review_colunms)

df_cc = df[df_c]

# %%
correlation_matrix = df_cc.corr(method='spearman')

# Plotando a matriz de correlação como um heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', vmin=-1, vmax=1)
plt.title('Matriz de Correlação (Spearman)')
plt.show()

# %% [markdown]
# Essa matriz de correlação nos traz algumas coisas interessantes como, por exemplo, conseguimos ver quais são os fatores que mais influência na nota final dada a uma cerveja. Vemos aqui, por exemplo, que a nota dada para o sabor tem uma influencia direta na nota final da cerveja. Já a aparência tem certa influência, mas não tanta.

# %% [markdown]
# vemos também que não faz sentido para nossa análise levar em consideração a data que o review foi feito

# %%
df = df.drop(columns=['review_time'],axis=1)

# %%
df
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 0                   1.5           2.0                2.5            stcules
# 1                   4.0           4.0                3.0        Likeburning
# 2                   4.0           3.5                3.0             JamesS
# 3                   3.5           3.5                3.0          GusterFan
# 4                   4.0           4.0                3.5           harpo111
# ...                 ...           ...                ...                ...
# 1586261             4.5           4.0                4.0          MasterSki
# 1586262             4.0           4.0                3.5          jrallen34
# 1586263             4.0           4.0                5.0           Phyl21ca
# 1586264             5.0           4.0                4.5          wordemupg
# 1586265             4.5           5.0                5.0              bobsy
#
#                               beer_style  review_palate  review_taste  \
# 0                             Hefeweizen            1.5           1.5
# 1                             Hefeweizen            4.0           3.5
# 2                             Hefeweizen            4.0           4.5
# 3                             Hefeweizen            3.0           3.5
# 4                             Hefeweizen            3.5           3.5
# ...                                  ...            ...           ...
# 1586261  Bière de Champagne / Bière Brut            4.5           4.0
# 1586262  Bière de Champagne / Bière Brut            4.5           4.0
# 1586263  Bière de Champagne / Bière Brut            4.0           4.0
# 1586264  Bière de Champagne / Bière Brut            4.5           4.5
# 1586265  Bière de Champagne / Bière Brut            4.5           4.5
#
#                      beer_name  beer_abv  beer_beerid  mean ibu
# 0                 Sausa Weizen       5.0        47986      12.5
# 1                   Hefeweizen       5.0        20575      12.5
# 2                  Hefe Weizen       4.5        73291      12.5
# 3                Wheezy Heifer       5.5        27229      12.5
# 4                  Hefe-Weizen       5.5         2776      12.5
# ...                        ...       ...          ...       ...
# 1586261  Dominus Vobiscum Brut      11.0        59014      40.0
# 1586262  Dominus Vobiscum Brut      11.0        59014      40.0
# 1586263  Dominus Vobiscum Brut      11.0        59014      40.0
# 1586264  Dominus Vobiscum Brut      11.0        59014      40.0
# 1586265  Dominus Vobiscum Brut      11.0        59014      40.0
#
# [1586266 rows x 11 columns]

# %%
beerid_counts = df['beer_beerid'].value_counts().reset_index()
beerid_counts.columns = ['beer_beerid', 'count']
beerid_counts
# Out:
#        beer_beerid  count
# 0             2093   3289
# 1              412   3110
# 2             1904   2999
# 3             1093   2727
# 4               92   2702
# ...            ...    ...
# 66046        59983      1
# 66047        40239      1
# 66048        72871      1
# 66049        56688      1
# 66050        47986      1
#
# [66051 rows x 2 columns]

# %%
beerid_counts['count'].describe()
# Out:
# count    66051.000000
# mean        24.015776
# std        110.838706
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          7.000000
# max       3289.000000
# Name: count, dtype: float64

# %%
profile_counts = df['review_profilename'].value_counts().reset_index()
beerid_counts.columns = ['review_profilename', 'count']

# %%
profile_counts
# Out:
#                  index  review_profilename
# 0       northyorksammy                5817
# 1        BuckeyeNation                4661
# 2          mikesgroove                4617
# 3            Thorpe429                3518
# 4        womencantsail                3497
# ...                ...                 ...
# 33382         adam7475                   1
# 33383  BayouBreweryRob                   1
# 33384          Calchas                   1
# 33385          JustinL                   1
# 33386           ScottF                   1
#
# [33387 rows x 2 columns]

# %%
profile_counts['review_profilename'].describe()
# Out:
# count    33387.000000
# mean        47.511487
# std        182.599759
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%         16.000000
# max       5817.000000
# Name: review_profilename, dtype: float64

# %% [markdown]
# Aqui vemos um pequeno problema, temos cervejas que foram avaliadas muito poucas vezes, assim como temos usuarios que avaliaram muito pouco. Opiniões de usuários que avaliaram apenas algumas vezes podem não ser tão confiáveis quanto as de usuários que avaliaram mais vezes. Da mesma forma, cervejas avaliadas poucas vezes podem ter avaliações menos consistentes e informativas. Avaliações com baixas ocorrências podem afetar análises estatísticas e modelagem. Modelos de recomendação, por exemplo, podem ter dificuldade em encontrar padrões significativos em avaliações escassas. Por isso, vamos excluir os usuarios que avaliaram pouco e as cervejas que foram pouco avaliadas

# %%
beerid_counts = df['beer_beerid'].value_counts()
profilename_counts = df['review_profilename'].value_counts()

# Filtrando cervejas com menos de 20 avaliações e usuários com menos de 10 avaliações
beerids_to_keep = beerid_counts[beerid_counts >= 25].index
profilenames_to_keep = profilename_counts[profilename_counts >= 15].index

# %% [markdown]
# "Perdemos" 20 mil dados no caminho

# %% [markdown]
# MODEL

# %% [markdown]
# Vamos iniciar com uma abordagem de filtragem demográfica, tirando a nota média de cada cerveja, e adicionando quantas vezes cada cerveja aparece, ou seja, foi avaliada.

# %%
df = df[df['beer_beerid'].isin(beerids_to_keep) & df['review_profilename'].isin(profilenames_to_keep)]
dem = df.drop_duplicates(subset=['beer_beerid'])
dem['beer_vote_count'] = df.groupby('beer_beerid')['beer_beerid'].transform('count')
# Out:
# /tmp/ipykernel_15072/2828247006.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dem['beer_vote_count'] = df.groupby('beer_beerid')['beer_beerid'].transform('count')

# %%
df
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 1                   4.0           4.0                3.0        Likeburning
# 26                  3.5           3.5                3.0          superspak
# 28                  4.0           4.0                3.0      Viciousknishs
# 29                  3.5           3.5                4.0      sixerofelixir
# 30                  4.0           4.0                4.5           Trystero
# ...                 ...           ...                ...                ...
# 1586242             4.0           4.0                4.5          clickpush
# 1586243             2.0           3.0                3.0    blitheringidiot
# 1586244             4.0           3.5                3.5          IntriqKen
# 1586245             4.0           3.5                4.0                Ego
# 1586246             4.0           3.5                4.0        GCBrewingCo
#
#                               beer_style  review_palate  review_taste  \
# 1                             Hefeweizen            4.0           3.5
# 26                            Hefeweizen            4.0           4.0
# 28                            Hefeweizen            3.5           3.5
# 29                            Hefeweizen            4.0           4.0
# 30                            Hefeweizen            4.5           4.0
# ...                                  ...            ...           ...
# 1586242  Bière de Champagne / Bière Brut            2.5           3.5
# 1586243  Bière de Champagne / Bière Brut            3.0           3.0
# 1586244  Bière de Champagne / Bière Brut            4.0           4.5
# 1586245  Bière de Champagne / Bière Brut            4.0           3.5
# 1586246  Bière de Champagne / Bière Brut            4.0           3.5
#
#                    beer_name  beer_abv  beer_beerid  mean ibu
# 1                 Hefeweizen       5.0        20575      12.5
# 26       Wild Frog Wheat Ale       6.0        36862      12.5
# 28       Wild Frog Wheat Ale       6.0        36862      12.5
# 29       Wild Frog Wheat Ale       6.0        36862      12.5
# 30       Wild Frog Wheat Ale       6.0        36862      12.5
# ...                      ...       ...          ...       ...
# 1586242       Krait Prestige       8.0        33766      40.0
# 1586243       Krait Prestige       8.0        33766      40.0
# 1586244       Krait Prestige       8.0        33766      40.0
# 1586245       Krait Prestige       8.0        33766      40.0
# 1586246       Krait Prestige       8.0        33766      40.0
#
# [1289815 rows x 11 columns]

# %%
user_avg_scores = df.groupby('review_profilename')['review_overall'].mean()

# Criar uma nova coluna 'avg_user_score' no DataFrame original
df['avg_user_score'] = df['review_profilename'].map(user_avg_scores)
# Out:
# /tmp/ipykernel_15072/762267316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['avg_user_score'] = df['review_profilename'].map(user_avg_scores)

# %%
df
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 1                   4.0           4.0                3.0        Likeburning
# 26                  3.5           3.5                3.0          superspak
# 28                  4.0           4.0                3.0      Viciousknishs
# 29                  3.5           3.5                4.0      sixerofelixir
# 30                  4.0           4.0                4.5           Trystero
# ...                 ...           ...                ...                ...
# 1586242             4.0           4.0                4.5          clickpush
# 1586243             2.0           3.0                3.0    blitheringidiot
# 1586244             4.0           3.5                3.5          IntriqKen
# 1586245             4.0           3.5                4.0                Ego
# 1586246             4.0           3.5                4.0        GCBrewingCo
#
#                               beer_style  review_palate  review_taste  \
# 1                             Hefeweizen            4.0           3.5
# 26                            Hefeweizen            4.0           4.0
# 28                            Hefeweizen            3.5           3.5
# 29                            Hefeweizen            4.0           4.0
# 30                            Hefeweizen            4.5           4.0
# ...                                  ...            ...           ...
# 1586242  Bière de Champagne / Bière Brut            2.5           3.5
# 1586243  Bière de Champagne / Bière Brut            3.0           3.0
# 1586244  Bière de Champagne / Bière Brut            4.0           4.5
# 1586245  Bière de Champagne / Bière Brut            4.0           3.5
# 1586246  Bière de Champagne / Bière Brut            4.0           3.5
#
#                    beer_name  beer_abv  beer_beerid  mean ibu  avg_user_score
# 1                 Hefeweizen       5.0        20575      12.5        3.423077
# 26       Wild Frog Wheat Ale       6.0        36862      12.5        4.038012
# 28       Wild Frog Wheat Ale       6.0        36862      12.5        3.966258
# 29       Wild Frog Wheat Ale       6.0        36862      12.5        3.663380
# 30       Wild Frog Wheat Ale       6.0        36862      12.5        4.240000
# ...                      ...       ...          ...       ...             ...
# 1586242       Krait Prestige       8.0        33766      40.0        3.824232
# 1586243       Krait Prestige       8.0        33766      40.0        3.669089
# 1586244       Krait Prestige       8.0        33766      40.0        3.955544
# 1586245       Krait Prestige       8.0        33766      40.0        3.893557
# 1586246       Krait Prestige       8.0        33766      40.0        3.957006
#
# [1289815 rows x 12 columns]

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['avg_user_score'], vert=False, widths=0.6, showfliers=True)

plt.title('Boxplot das Médias de Notas dos Usuários')
plt.xlabel('Média da Nota')
plt.ylabel('Usuário')

plt.show()

# %%
Q1 = df['avg_user_score'].quantile(0.25)
Q3 = df['avg_user_score'].quantile(0.75)
IQR = Q3 - Q1

# Definir limites para identificar outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identificar outliers
outliers = df[(df['avg_user_score'] < lower_bound) | (df['avg_user_score'] > upper_bound)]

outliers
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 58                  4.0           3.5                3.5             nick76
# 82                  3.5           3.5                4.0                JDV
# 143                 2.0           3.0                3.5         Arbitrator
# 194                 3.5           3.5                3.5        newcastleme
# 195                 4.0           3.5                4.0        newcastleme
# ...                 ...           ...                ...                ...
# 1586028             3.0           3.5                2.0                JDV
# 1586065             3.5           3.5                3.5           rastaman
# 1586074             3.5           3.5                4.0         kojevergas
# 1586162             2.0           3.0                1.0          flyingpig
# 1586241             4.5           3.5                4.0            Sudsdog
#
#                               beer_style  review_palate  review_taste  \
# 58                            Hefeweizen            3.0           4.0
# 82                            Hefeweizen            3.0           3.5
# 143                           Hefeweizen            2.0           3.0
# 194                           Hefeweizen            4.0           3.5
# 195                           Hefeweizen            3.5           4.0
# ...                                  ...            ...           ...
# 1586028  Bière de Champagne / Bière Brut            2.0           3.0
# 1586065  Bière de Champagne / Bière Brut            3.5           3.5
# 1586074  Bière de Champagne / Bière Brut            3.5           4.0
# 1586162  Bière de Champagne / Bière Brut            2.0           2.5
# 1586241  Bière de Champagne / Bière Brut            4.5           4.0
#
#                                    beer_name  beer_abv  beer_beerid  mean ibu  \
# 58                       Wild Frog Wheat Ale       6.0        36862      12.5
# 82                       Wild Frog Wheat Ale       6.0        36862      12.5
# 143            Kirkland Signature Hefeweizen       5.5        48519      12.5
# 194                               Hefeweizen       5.0        20575      12.5
# 195                               Hefeweizen       5.0        20575      12.5
# ...                                      ...       ...          ...       ...
# 1586028    Malheur Bière Brut (Brut Reserve)      12.0         5818      40.0
# 1586065    Malheur Bière Brut (Brut Reserve)      12.0         5818      40.0
# 1586074  Malheur Brut Noir (Black Chocolate)      12.0        16487      40.0
# 1586162                          Kasteel Cru       5.2        26652      40.0
# 1586241                       Krait Prestige       8.0        33766      40.0
#
#          avg_user_score
# 58             3.318501
# 82             3.332474
# 143            3.043307
# 194            3.080000
# 195            3.080000
# ...                 ...
# 1586028        3.332474
# 1586065        3.131579
# 1586074        3.010606
# 1586162        3.267241
# 1586241        4.409341
#
# [33310 rows x 12 columns]

# %%
df = df[(df['avg_user_score'] >= lower_bound) & (df['avg_user_score'] <= upper_bound)]

# %%
df
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 1                   4.0           4.0                3.0        Likeburning
# 26                  3.5           3.5                3.0          superspak
# 28                  4.0           4.0                3.0      Viciousknishs
# 29                  3.5           3.5                4.0      sixerofelixir
# 30                  4.0           4.0                4.5           Trystero
# ...                 ...           ...                ...                ...
# 1586242             4.0           4.0                4.5          clickpush
# 1586243             2.0           3.0                3.0    blitheringidiot
# 1586244             4.0           3.5                3.5          IntriqKen
# 1586245             4.0           3.5                4.0                Ego
# 1586246             4.0           3.5                4.0        GCBrewingCo
#
#                               beer_style  review_palate  review_taste  \
# 1                             Hefeweizen            4.0           3.5
# 26                            Hefeweizen            4.0           4.0
# 28                            Hefeweizen            3.5           3.5
# 29                            Hefeweizen            4.0           4.0
# 30                            Hefeweizen            4.5           4.0
# ...                                  ...            ...           ...
# 1586242  Bière de Champagne / Bière Brut            2.5           3.5
# 1586243  Bière de Champagne / Bière Brut            3.0           3.0
# 1586244  Bière de Champagne / Bière Brut            4.0           4.5
# 1586245  Bière de Champagne / Bière Brut            4.0           3.5
# 1586246  Bière de Champagne / Bière Brut            4.0           3.5
#
#                    beer_name  beer_abv  beer_beerid  mean ibu  avg_user_score
# 1                 Hefeweizen       5.0        20575      12.5        3.423077
# 26       Wild Frog Wheat Ale       6.0        36862      12.5        4.038012
# 28       Wild Frog Wheat Ale       6.0        36862      12.5        3.966258
# 29       Wild Frog Wheat Ale       6.0        36862      12.5        3.663380
# 30       Wild Frog Wheat Ale       6.0        36862      12.5        4.240000
# ...                      ...       ...          ...       ...             ...
# 1586242       Krait Prestige       8.0        33766      40.0        3.824232
# 1586243       Krait Prestige       8.0        33766      40.0        3.669089
# 1586244       Krait Prestige       8.0        33766      40.0        3.955544
# 1586245       Krait Prestige       8.0        33766      40.0        3.893557
# 1586246       Krait Prestige       8.0        33766      40.0        3.957006
#
# [1256505 rows x 12 columns]

# %%
beerid_avg_review = df.groupby('beer_beerid')['review_overall'].mean().reset_index()

# Renomeando a coluna para refletir a média
beerid_avg_review.rename(columns={'review_overall': 'avg_beer_score'}, inplace=True)

# %%
beerid_avg_review
# Out:
#       beer_beerid  avg_beer_score
# 0               5        3.544737
# 1               6        3.700127
# 2               7        3.252577
# 3               8        3.617188
# 4               9        3.409524
# ...           ...             ...
# 8035        76144        4.140000
# 8036        76323        4.000000
# 8037        76525        4.019608
# 8038        76571        3.722222
# 8039        76816        4.023256
#
# [8040 rows x 2 columns]

# %%
dem = pd.merge(beerid_avg_review,dem, on='beer_beerid',how='inner')

# %%
dem
# Out:
#       beer_beerid  avg_beer_score  review_overall  review_aroma  \
# 0               5        3.544737             4.0           3.5
# 1               6        3.700127             4.0           3.5
# 2               7        3.252577             3.5           3.0
# 3               8        3.617188             3.5           2.5
# 4               9        3.409524             2.5           2.0
# ...           ...             ...             ...           ...
# 8035        76144        4.140000             4.0           4.0
# 8036        76323        4.000000             4.5           4.0
# 8037        76525        4.019608             4.5           5.0
# 8038        76571        3.722222             4.0           4.0
# 8039        76816        4.023256             4.0           3.5
#
#       review_appearance review_profilename              beer_style  \
# 0                   3.5         Backer2004            Vienna Lager
# 1                   4.0              Strix       English Brown Ale
# 2                   3.0              matty  Fruit / Vegetable Beer
# 3                   3.5        optimator13  American Adjunct Lager
# 4                   2.0            walleye     American Pale Lager
# ...                 ...                ...                     ...
# 8035                4.0          SHODriver     American Strong Ale
# 8036                4.5        pmlondrigan        Belgian Pale Ale
# 8037                4.5          seanwhite            American IPA
# 8038                4.5              Luigi     Munich Helles Lager
# 8039                4.0           JoEBoBpr                Rye Beer
#
#       review_palate  review_taste  \
# 0               3.5           4.0
# 1               3.5           3.5
# 2               3.5           3.0
# 3               4.0           3.0
# 4               2.0           2.0
# ...             ...           ...
# 8035            4.0           4.5
# 8036            3.5           4.5
# 8037            4.0           4.0
# 8038            4.5           4.0
# 8039            4.0           4.0
#
#                                               beer_name  beer_abv  mean ibu  \
# 0                                                 Amber       4.5      24.0
# 1                                              Turbodog       5.6      20.0
# 2                                           Purple Haze       4.2      20.0
# 3                                                 Wheat       4.2      12.0
# 4                                                Golden       4.2      30.0
# ...                                                 ...       ...       ...
# 8035                        He'Brew Jewbelation Fifteen      15.0      75.0
# 8036                                         Rayon Vert       7.0      25.0
# 8037  The Alchemist / Ninkasi / Stone - More Brown T...       7.4      55.0
# 8038                         Samuel Adams Alpine Spring       5.8      19.0
# 8039                     Sierra Nevada Ruthless Rye IPA       6.6      60.0
#
#       beer_vote_count
# 0                 402
# 1                 820
# 2                 611
# 3                  65
# 4                 113
# ...               ...
# 8035               50
# 8036               24
# 8037               52
# 8038               28
# 8039               45
#
# [8040 rows x 13 columns]

# %% [markdown]
# Podemos usar as avaliações médias das cervejas como pontuação, mas usar isso não será justo, pois uma cerveja com classificação média de 4.5 e apenas 3 votos não pode ser considerado melhor do que o filme com classificação média de 4, mas 40 votos. Portanto, usarei a classificação ponderada (wr)

# %%
C= df['review_overall'].mean()
C
# Out:
# 3.844084185896594

# %% [markdown]
# Portanto, a classificação média para todas as cervejas é de aproximadamente 3.8 em uma escala de 10. O próximo passo é determinar um valor apropriado para m, os votos mínimos necessários para serem listados no gráfico. Usaremos o percentil 90 como ponto de corte. Em outras palavras, para que uma cerveja apareça nas paradas, ele deve ter mais votos do que pelo menos 80% dos filmes da lista.

# %%
m= dem['beer_vote_count'].quantile(0.8)
m
# Out:
# 208.0

# %%
q_beers = dem.copy().loc[dem['beer_vote_count'] >= m]
q_beers.shape
# Out:
# (1615, 13)

# %% [markdown]
# Vemos que existem 1837 cervejas que se qualificam para estar nesta lista. Agora, precisamos calcular nossa métrica para cada cerveja qualificada. Para fazer isso, vamos definir uma função, weighted_rating() e definir uma nova pontuação de recurso, da qual calcularemos o valor aplicando essa função ao nosso DataFrame de cervejas qualificados

# %%
def weighted_rating(x, m=m, C=C):
    v = x['beer_vote_count']
    R = x['avg_beer_score']
    
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
q_beers['score'] = q_beers.apply(weighted_rating, axis=1)

# %%
q_beers = q_beers.sort_values('score', ascending=False)

# %%
q_beers[['beer_name','beer_style', 'beer_vote_count', 'avg_beer_score', 'score']].head(10)
# Out:
#                           beer_name                        beer_style  \
# 2564                Pliny The Elder    American Double / Imperial IPA
# 845        Trappist Westvleteren 12                  Quadrupel (Quad)
# 420   Weihenstephaner Hefeweissbier                        Hefeweizen
# 6192    Founders CBS Imperial Stout  American Double / Imperial Stout
# 3733              Pliny The Younger    American Double / Imperial IPA
# 3339                   Heady Topper    American Double / Imperial IPA
# 4758                      The Abyss  American Double / Imperial Stout
# 502         Trappist Westvleteren 8                            Dubbel
# 4350         Sculpin India Pale Ale                      American IPA
# 3264           Tröegs Nugget Nectar          American Amber / Red Ale
#
#       beer_vote_count  avg_beer_score     score
# 2564             2164        4.580907  4.516295
# 845              1136        4.605621  4.487764
# 420              1806        4.507118  4.438642
# 6192              578        4.570018  4.377913
# 3733              529        4.577148  4.370259
# 3339              425        4.623487  4.367380
# 4758             1259        4.439195  4.354816
# 502               678        4.509188  4.353047
# 4350             1249        4.427459  4.344177
# 3264             1786        4.385960  4.329435

# %% [markdown]
# Uhu, aqui temos nossa primeira forma de recomendação, mas note que esta forma é algo "Geral", Ou seja, não capta os gostos individuais de cada cliente.
# Para isso, vamos brincar com a filtragem colaborativa.

# %% [markdown]
# FILTRAGEM COLABORATIVA

# %%
from surprise import Reader , Dataset, SVD
#from surprise import evaluate

# %% [markdown]
# Ops, problema, aqui não achamoso modeulo evaluate, mas com uma breve busca vemos que ele virou cross_validate

# %%
from surprise.model_selection import cross_validate

# %%
reader = Reader()
ratings = df[['review_profilename','beer_beerid','review_overall']]

# %%
ratings
# Out:
#         review_profilename  beer_beerid  review_overall
# 1              Likeburning        20575             4.0
# 26               superspak        36862             3.5
# 28           Viciousknishs        36862             4.0
# 29           sixerofelixir        36862             3.5
# 30                Trystero        36862             4.0
# ...                    ...          ...             ...
# 1586242          clickpush        33766             4.0
# 1586243    blitheringidiot        33766             2.0
# 1586244          IntriqKen        33766             4.0
# 1586245                Ego        33766             4.0
# 1586246        GCBrewingCo        33766             4.0
#
# [1256505 rows x 3 columns]

# %% [markdown]
# Com base na distribuição plotada vamos categorizar nossos dados em 3 classes, bom médio e ruim, onde vamos normalizar com 0, 1 e 2

# %%
'''def map_review(value):
    if value <= 3:
        return 0
    elif 3 < value < 4.5:
        return 1
    else:
        return 2'''
# Out:
# 'def map_review(value):\n    if value <= 3:\n        return 0\n    elif 3 < value < 4.5:\n        return 1\n    else:\n        return 2'

# %%
'''ratings['review_mapped'] = df['review_overall'].apply(map_review)
ratings = ratings.drop(columns=['review_overall'])'''
# Out:
# "ratings['review_mapped'] = df['review_overall'].apply(map_review)\nratings = ratings.drop(columns=['review_overall'])"

# %%
ratings
# Out:
#         review_profilename  beer_beerid  review_overall
# 1              Likeburning        20575             4.0
# 26               superspak        36862             3.5
# 28           Viciousknishs        36862             4.0
# 29           sixerofelixir        36862             3.5
# 30                Trystero        36862             4.0
# ...                    ...          ...             ...
# 1586242          clickpush        33766             4.0
# 1586243    blitheringidiot        33766             2.0
# 1586244          IntriqKen        33766             4.0
# 1586245                Ego        33766             4.0
# 1586246        GCBrewingCo        33766             4.0
#
# [1256505 rows x 3 columns]

# %% [markdown]
# ----------------------------------

# %%
data = Dataset.load_from_df(ratings[['review_profilename','beer_beerid','review_overall']], reader)

# %%
from surprise.model_selection import KFold

svd = SVD()
kf = KFold(n_splits=5)
kf.split(data)
cross_validate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.57798291, 0.57947992, 0.5764562 , 0.58040834, 0.57917812]),
#  'test_mae': array([0.43318165, 0.43423697, 0.43237574, 0.43521785, 0.43343949]),
#  'fit_time': (22.96357250213623,
#   21.85675072669983,
#   25.178075075149536,
#   17.610496044158936,
#   23.63354802131653),
#  'test_time': (2.7331929206848145,
#   4.01171350479126,
#   3.259394645690918,
#   3.0964558124542236,
#   2.877950668334961)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
ratings[ratings['review_profilename'] == 'Strix']
# Out:
#         review_profilename  beer_beerid  review_overall
# 844                  Strix        48434             4.0
# 2029                 Strix          772             2.5
# 3116                 Strix           82             4.0
# 7511                 Strix        37586             4.0
# 7847                 Strix        47539             4.0
# ...                    ...          ...             ...
# 1564895              Strix         1708             5.0
# 1571300              Strix         1934             4.0
# 1572127              Strix        28944             4.5
# 1575916              Strix        35720             2.5
# 1580091              Strix         6104             3.5
#
# [470 rows x 3 columns]

# %%
svd.predict('Strix', 26432)
# Out:
# Prediction(uid='Strix', iid=26432, r_ui=None, est=3.7322647353117384, details={'was_impossible': False})

# %% [markdown]
# Desse jeito ainda não conseguimos recomendar, apenas mostrar o resultado de previsão para um usuário já conhecido

# %%
df
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 1                   4.0           4.0                3.0        Likeburning
# 26                  3.5           3.5                3.0          superspak
# 28                  4.0           4.0                3.0      Viciousknishs
# 29                  3.5           3.5                4.0      sixerofelixir
# 30                  4.0           4.0                4.5           Trystero
# ...                 ...           ...                ...                ...
# 1586242             4.0           4.0                4.5          clickpush
# 1586243             2.0           3.0                3.0    blitheringidiot
# 1586244             4.0           3.5                3.5          IntriqKen
# 1586245             4.0           3.5                4.0                Ego
# 1586246             4.0           3.5                4.0        GCBrewingCo
#
#                               beer_style  review_palate  review_taste  \
# 1                             Hefeweizen            4.0           3.5
# 26                            Hefeweizen            4.0           4.0
# 28                            Hefeweizen            3.5           3.5
# 29                            Hefeweizen            4.0           4.0
# 30                            Hefeweizen            4.5           4.0
# ...                                  ...            ...           ...
# 1586242  Bière de Champagne / Bière Brut            2.5           3.5
# 1586243  Bière de Champagne / Bière Brut            3.0           3.0
# 1586244  Bière de Champagne / Bière Brut            4.0           4.5
# 1586245  Bière de Champagne / Bière Brut            4.0           3.5
# 1586246  Bière de Champagne / Bière Brut            4.0           3.5
#
#                    beer_name  beer_abv  beer_beerid  mean ibu  avg_user_score
# 1                 Hefeweizen       5.0        20575      12.5        3.423077
# 26       Wild Frog Wheat Ale       6.0        36862      12.5        4.038012
# 28       Wild Frog Wheat Ale       6.0        36862      12.5        3.966258
# 29       Wild Frog Wheat Ale       6.0        36862      12.5        3.663380
# 30       Wild Frog Wheat Ale       6.0        36862      12.5        4.240000
# ...                      ...       ...          ...       ...             ...
# 1586242       Krait Prestige       8.0        33766      40.0        3.824232
# 1586243       Krait Prestige       8.0        33766      40.0        3.669089
# 1586244       Krait Prestige       8.0        33766      40.0        3.955544
# 1586245       Krait Prestige       8.0        33766      40.0        3.893557
# 1586246       Krait Prestige       8.0        33766      40.0        3.957006
#
# [1256505 rows x 12 columns]

# %%
plt.hist(df['review_overall'], bins=25, edgecolor='black')

# Adicione rótulos e título ao gráfico
plt.xlabel('Average review Score')
plt.ylabel('Frequency')
plt.title('Distribution of Average User Scores')
# Out:
# Text(0.5, 1.0, 'Distribution of Average User Scores')

# %% [markdown]
# Uau, o comportamento dos usuários é muito "proximo", como será que vamos captar esses gostos pessoais
#
# 0 a 3
# 3.5 a 4.5
# 4.6 a 5

# %%
n12 = df.loc[df['review_overall']<3]
n3 = df.loc[df['review_overall'] == 3]
n35 = df.loc[df['review_overall'] == 3.5]
n4 = df.loc[df['review_overall'] == 4]
n45 = df.loc[df['review_overall'] == 4.5]
n5 = df.loc[df['review_overall'] == 5]

# %%
n12.shape
# Out:
# (81913, 12)

# %%
n3.shape
# Out:
# (124068, 12)

# %%
n35.shape
# Out:
# (239007, 12)

# %%
n4.shape
# Out:
# (476920, 12)

# %%
n45.shape
# Out:
# (265918, 12)

# %%
n5.shape
# Out:
# (68679, 12)

# %%
n35 = n35.sample(n=132000, random_state=42)
n4 = n4.sample(n=145000, random_state=42)
n45 = n45.sample(n=135000, random_state=42)

# %%
print(n12.shape,n3.shape,
n35.shape,
n4.shape,
n45.shape,
n5.shape)
# Out:
# (81913, 12) (124068, 12) (132000, 12) (145000, 12) (135000, 12) (68679, 12)

# %% [markdown]
# Parece que nossas classes estão mais balanceadas agora, porém perdemos quase um milhão de dados no processo

# %%
dataframes = [n12, n3, n35, n4, n45, n5]

# Crie um DataFrame vazio com o mesmo esquema
df2 = pd.DataFrame(columns=dataframes[0].columns)

# Adicione os DataFrames ao DataFrame combinado (df2)
for df in dataframes:
    df2 = df2.append(df, ignore_index=True)
# Out:
# /tmp/ipykernel_15072/2827262089.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(df, ignore_index=True)

# %%
df2
# Out:
#         review_overall  review_aroma  review_appearance review_profilename  \
# 0                  2.5           4.5                2.5      JamnesCameron
# 1                  2.0           2.0                2.0             jsh420
# 2                  2.5           4.0                3.5      GatorBeerNerd
# 3                  2.5           3.5                3.5            AltBock
# 4                  2.5           3.0                3.0       bluejacket74
# ...                ...           ...                ...                ...
# 686655             5.0           4.0                4.5         rajendra82
# 686656             5.0           4.0                4.5     DaPeculierDane
# 686657             5.0           4.0                4.0            Bobikel
# 686658             5.0           4.5                5.0            marburg
# 686659             5.0           3.0                3.5        SilentSabre
#
#                              beer_style  review_palate  review_taste  \
# 0                            Hefeweizen            2.5           2.5
# 1                            Hefeweizen            2.0           2.0
# 2                            Hefeweizen            3.0           3.5
# 3                            Hefeweizen            2.5           3.0
# 4                            Hefeweizen            3.5           2.5
# ...                                 ...            ...           ...
# 686655  Bière de Champagne / Bière Brut            4.5           4.0
# 686656  Bière de Champagne / Bière Brut            5.0           4.5
# 686657  Bière de Champagne / Bière Brut            4.0           3.5
# 686658  Bière de Champagne / Bière Brut            4.5           4.5
# 686659  Bière de Champagne / Bière Brut            3.5           3.5
#
#                                   beer_name  beer_abv beer_beerid  mean ibu  \
# 0                       Wild Frog Wheat Ale       6.0       36862      12.5
# 1                       Wild Frog Wheat Ale       6.0       36862      12.5
# 2                       Wild Frog Wheat Ale       6.0       36862      12.5
# 3                       Wild Frog Wheat Ale       6.0       36862      12.5
# 4                       Wild Frog Wheat Ale       6.0       36862      12.5
# ...                                     ...       ...         ...       ...
# 686655  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686656  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686657  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686658  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686659                       Krait Prestige       8.0       33766      40.0
#
#         avg_user_score
# 0             3.968675
# 1             3.678862
# 2             3.984914
# 3             3.635234
# 4             3.874805
# ...                ...
# 686655        4.000665
# 686656        3.831050
# 686657        3.993590
# 686658        4.111324
# 686659        3.668684
#
# [686660 rows x 12 columns]

# %%
plt.hist(df2['review_overall'], bins=40, edgecolor='black')

# Adicione rótulos e título ao gráfico
plt.xlabel('Average review Score')
plt.ylabel('Frequency')
plt.title('Distribution of Average User Scores')
# Out:
# Text(0.5, 1.0, 'Distribution of Average User Scores')

# %%
uvalidacao = df2['review_profilename'].sample(n=50,random_state=42).unique()

df_treinamento = df2[~df2['review_profilename'].isin(uvalidacao)]

# Filtra o DataFrame original para criar o conjunto de validação (apenas com os nomes únicos)
df_validacao = df2[df2['review_profilename'].isin(uvalidacao)]

# %%
df_treinamento
# Out:
#         review_overall  review_aroma  review_appearance review_profilename  \
# 0                  2.5           4.5                2.5      JamnesCameron
# 1                  2.0           2.0                2.0             jsh420
# 2                  2.5           4.0                3.5      GatorBeerNerd
# 3                  2.5           3.5                3.5            AltBock
# 5                  1.5           3.0                3.5           nlmartin
# ...                ...           ...                ...                ...
# 686655             5.0           4.0                4.5         rajendra82
# 686656             5.0           4.0                4.5     DaPeculierDane
# 686657             5.0           4.0                4.0            Bobikel
# 686658             5.0           4.5                5.0            marburg
# 686659             5.0           3.0                3.5        SilentSabre
#
#                              beer_style  review_palate  review_taste  \
# 0                            Hefeweizen            2.5           2.5
# 1                            Hefeweizen            2.0           2.0
# 2                            Hefeweizen            3.0           3.5
# 3                            Hefeweizen            2.5           3.0
# 5                            Hefeweizen            2.0           1.5
# ...                                 ...            ...           ...
# 686655  Bière de Champagne / Bière Brut            4.5           4.0
# 686656  Bière de Champagne / Bière Brut            5.0           4.5
# 686657  Bière de Champagne / Bière Brut            4.0           3.5
# 686658  Bière de Champagne / Bière Brut            4.5           4.5
# 686659  Bière de Champagne / Bière Brut            3.5           3.5
#
#                                   beer_name  beer_abv beer_beerid  mean ibu  \
# 0                       Wild Frog Wheat Ale       6.0       36862      12.5
# 1                       Wild Frog Wheat Ale       6.0       36862      12.5
# 2                       Wild Frog Wheat Ale       6.0       36862      12.5
# 3                       Wild Frog Wheat Ale       6.0       36862      12.5
# 5                       Wild Frog Wheat Ale       6.0       36862      12.5
# ...                                     ...       ...         ...       ...
# 686655  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686656  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686657  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686658  Malheur Brut Noir (Black Chocolate)      12.0       16487      40.0
# 686659                       Krait Prestige       8.0       33766      40.0
#
#         avg_user_score
# 0             3.968675
# 1             3.678862
# 2             3.984914
# 3             3.635234
# 5             3.785891
# ...                ...
# 686655        4.000665
# 686656        3.831050
# 686657        3.993590
# 686658        4.111324
# 686659        3.668684
#
# [667253 rows x 12 columns]

# %%
df_validacao
# Out:
#         review_overall  review_aroma  review_appearance review_profilename  \
# 4                  2.5           3.0                3.0       bluejacket74
# 74                 2.0           3.5                4.0           ppoitras
# 126                2.5           2.5                2.5       ChainGangGuy
# 135                2.0           2.0                2.0           Phyl21ca
# 189                2.5           2.0                3.5           Phyl21ca
# ...                ...           ...                ...                ...
# 686141             5.0           4.5                4.5      francisweizen
# 686334             5.0           4.5                4.5           ppoitras
# 686357             5.0           4.0                4.0              AlexJ
# 686547             5.0           4.0                3.5              AlexJ
# 686606             5.0           4.0                4.0            pzrhsau
#
#                              beer_style  review_palate  review_taste  \
# 4                            Hefeweizen            3.5           2.5
# 74                           Hefeweizen            2.5           2.5
# 126                          Hefeweizen            3.0           3.0
# 135                          Hefeweizen            1.5           1.5
# 189                          Hefeweizen            2.0           2.5
# ...                                 ...            ...           ...
# 686141                           Gueuze            5.0           4.5
# 686334                           Gueuze            5.0           4.5
# 686357                           Gueuze            4.0           4.0
# 686547                             Gose            3.5           4.0
# 686606  Bière de Champagne / Bière Brut            5.0           4.0
#
#                                 beer_name  beer_abv beer_beerid  mean ibu  \
# 4                     Wild Frog Wheat Ale       6.0       36862      12.5
# 74                             Hefeweizen       5.0       30099      12.5
# 126                         In-Heat Wheat       4.7        2249      12.5
# 135                         In-Heat Wheat       4.7        2249      12.5
# 189                 Hitachino Nest Weizen       5.0        2042      12.5
# ...                                   ...       ...         ...       ...
# 686141  Drie Fonteinen Oude Geuze Vintage       6.0       30517       5.0
# 686334        Lindemans Gueuze Cuvée René       5.0        6104       5.0
# 686357                   Lindemans Gueuze       4.0        3566       5.0
# 686547                     Leipziger Gose       4.6       10683       8.5
# 686606                           Infinium      10.3       64089      40.0
#
#         avg_user_score
# 4             3.874805
# 74            3.998701
# 126           3.552719
# 135           3.486676
# 189           3.486676
# ...                ...
# 686141        4.047570
# 686334        3.998701
# 686357        3.961818
# 686547        3.961818
# 686606        3.966165
#
# [19407 rows x 12 columns]

# %%
reader = Reader()
ratings = df_treinamento[['review_profilename', 'beer_beerid', 'review_overall']]
ratings
# Out:
#        review_profilename beer_beerid  review_overall
# 0           JamnesCameron       36862             2.5
# 1                  jsh420       36862             2.0
# 2           GatorBeerNerd       36862             2.5
# 3                 AltBock       36862             2.5
# 5                nlmartin       36862             1.5
# ...                   ...         ...             ...
# 686655         rajendra82       16487             5.0
# 686656     DaPeculierDane       16487             5.0
# 686657            Bobikel       16487             5.0
# 686658            marburg       16487             5.0
# 686659        SilentSabre       33766             5.0
#
# [667253 rows x 3 columns]

# %%
data = Dataset.load_from_df(ratings[['review_profilename', 'beer_beerid', 'review_overall']], reader)

svd = SVD()
kf = KFold(n_splits=5)
kf.split(data)
cross_validate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.69798669, 0.69493148, 0.69825956, 0.69410166, 0.69665126]),
#  'test_mae': array([0.54216545, 0.54014026, 0.54173497, 0.53960601, 0.54049017]),
#  'fit_time': (11.614962816238403,
#   9.674515008926392,
#   11.003522634506226,
#   12.533280849456787,
#   12.664594173431396),
#  'test_time': (1.9121685028076172,
#   1.117382287979126,
#   1.5541069507598877,
#   1.421100378036499,
#   1.6864943504333496)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
ratings
# Out:
#        review_profilename beer_beerid  review_overall
# 0           JamnesCameron       36862             2.5
# 1                  jsh420       36862             2.0
# 2           GatorBeerNerd       36862             2.5
# 3                 AltBock       36862             2.5
# 5                nlmartin       36862             1.5
# ...                   ...         ...             ...
# 686655         rajendra82       16487             5.0
# 686656     DaPeculierDane       16487             5.0
# 686657            Bobikel       16487             5.0
# 686658            marburg       16487             5.0
# 686659        SilentSabre       33766             5.0
#
# [667253 rows x 3 columns]

# %%
ratings[ratings['review_profilename'] == 'JamnesCameron']
# Out:
#        review_profilename beer_beerid  review_overall
# 0           JamnesCameron       36862             2.5
# 1882        JamnesCameron        2653             2.5
# 2444        JamnesCameron       17538             1.5
# 2856        JamnesCameron       34085             2.0
# 3749        JamnesCameron       61128             1.5
# ...                   ...         ...             ...
# 684203      JamnesCameron        6354             5.0
# 685803      JamnesCameron       49092             5.0
# 686504      JamnesCameron        2595             5.0
# 686563      JamnesCameron       10683             5.0
# 686603      JamnesCameron       64089             5.0
#
# [243 rows x 3 columns]

# %%
svd.predict('Strix', 64228)
# Out:
# Prediction(uid='Strix', iid=64228, r_ui=None, est=4.686557898415746, details={'was_impossible': False})

# %%
ratings
# Out:
#        review_profilename beer_beerid  review_overall
# 0           JamnesCameron       36862             2.5
# 1                  jsh420       36862             2.0
# 2           GatorBeerNerd       36862             2.5
# 3                 AltBock       36862             2.5
# 5                nlmartin       36862             1.5
# ...                   ...         ...             ...
# 686655         rajendra82       16487             5.0
# 686656     DaPeculierDane       16487             5.0
# 686657            Bobikel       16487             5.0
# 686658            marburg       16487             5.0
# 686659        SilentSabre       33766             5.0
#
# [667253 rows x 3 columns]

# %%
#beers_id = df['beer_beerid']
df3 = ratings.loc[ratings['review_profilename'] == 'JamnesCameron']
beers_id = df3['beer_beerid']
df3
# Out:
#        review_profilename beer_beerid  review_overall
# 0           JamnesCameron       36862             2.5
# 1882        JamnesCameron        2653             2.5
# 2444        JamnesCameron       17538             1.5
# 2856        JamnesCameron       34085             2.0
# 3749        JamnesCameron       61128             1.5
# ...                   ...         ...             ...
# 684203      JamnesCameron        6354             5.0
# 685803      JamnesCameron       49092             5.0
# 686504      JamnesCameron        2595             5.0
# 686563      JamnesCameron       10683             5.0
# 686603      JamnesCameron       64089             5.0
#
# [243 rows x 3 columns]

# %%
def recomendar(user):
    df3 = df2.loc[df2['review_profilename'] == user]
    beers_id = df3['beer_beerid']
    notas = []
    cervejas = []

    for b in beers_id:
        pred = svd.predict(user, b)
        nota = pred.est
        cerveja_id = pred.iid
        notas.append(nota)
        cervejas.append(cerveja_id)

    indice_max_nota = notas.index(max(notas))
    cerveja_recomendada = cervejas[indice_max_nota]

    return cerveja_recomendada

# %%
print(recomendar('JamnesCameron'))
# Out:
# 7971

# %% [markdown]
# Uau, no nosso primeiro teste tivemos como recomendação uma cerveja que o usuário avaliou como 5

# %% [markdown]
# vamos agora ver o quão distante nossas recomendações estão da nota máxima que um usuário deu

# %%
users = ratings['review_profilename']
users = users.sample(n= 1200, random_state=42)

# %%
err = []

for u in users:
    cr = recomendar(u)
    nmax = ratings[ratings['review_profilename'] == u]['review_overall'].max()
    nd = ratings.loc[(ratings['review_profilename'] == u) & (ratings['beer_beerid'] == cr), 'review_overall'].values
    print(nd)

    if len(nd) > 0:  # Verifique se há valores em nd antes de calcular o erro
        error = abs(nmax - nd[0])  # Use nd[0] para obter o valor único
        err.append(error)
        print(f"Usuário: {u}, Cerveja Recomendada: {cr}, Nota Máxima: {nmax}, Nota Recomendada: {nd[0]}, Erro: {error}")
    else:
        print(f"Usuário: {u}, Cerveja Recomendada: {cr}, Nota Máxima: {nmax}, Nenhuma nota encontrada para a cerveja recomendada")

# Calcule o erro médio apenas se houver erros na lista err
if err:
    average_error = sum(err) / len(err)
    print('ERRO MÉDIO:', average_error)
else:
    print('Nenhum erro calculado.')
# Out:
# [5.]
# Usuário: thetomG, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: iheartsheafstout, Cerveja Recomendada: 927, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Bitterbill, Cerveja Recomendada: 44942, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Jcdolan, Cerveja Recomendada: 2093, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: wahhmaster, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: olympuszymurgus, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: mactrail, Cerveja Recomendada: 7971, Nota Máxima: 4.5, Nota Recomendada: 3.5, Erro: 1.0
# [5.]
# Usuário: jdhilt, Cerveja Recomendada: 155, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: soupyman10, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: cdkrenz, Cerveja Recomendada: 46849, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: taez555, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: mtnbikerpa, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: Brad007, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [4.5]
# Usuário: mcowgill, Cerveja Recomendada: 11757, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mickeymac, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Cwrw, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: RedChrome, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: MrHurmateeowish, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: RichLightweight, Cerveja Recomendada: 129, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: AmericanGothic, Cerveja Recomendada: 61100, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: JohnfromDublin, Cerveja Recomendada: 731, Nota Máxima: 4.5, Nota Recomendada: 3.5, Erro: 1.0
# [5.]
# Usuário: colts9016, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Chico1985, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: dirtylou, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: alcstradamus, Cerveja Recomendada: 8626, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: humanawho, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: CampusCrew, Cerveja Recomendada: 1558, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: Backer2004, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Thickfreakness, Cerveja Recomendada: 41815, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: UnskinnyHop, Cerveja Recomendada: 1904, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Tucquan, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: RedDiamond, Cerveja Recomendada: 34420, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: blitheringidiot, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: emmasdad, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: DovaliHops, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: zeff80, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: junjun, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: ThistleKing, Cerveja Recomendada: 226, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: kbutler1, Cerveja Recomendada: 36316, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jahred, Cerveja Recomendada: 221, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: DrJay, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: bboven, Cerveja Recomendada: 8951, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Boilermaker88, Cerveja Recomendada: 857, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: chicagoabbot, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: JoshD, Cerveja Recomendada: 9478, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: NeroFiddled, Cerveja Recomendada: 28296, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [4.5]
# Usuário: maleman, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: RedChrome, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4. 5.]
# Usuário: longpondbeerman, Cerveja Recomendada: 1558, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: zeff80, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: nickss, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: StonedTrippin, Cerveja Recomendada: 73910, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: josiahschlender, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Kwak, Cerveja Recomendada: 56973, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: maitiuoceallaigh, Cerveja Recomendada: 16520, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Gmann, Cerveja Recomendada: 61100, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mothman, Cerveja Recomendada: 38094, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: bradybeer, Cerveja Recomendada: 6549, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: j37geogaddi, Cerveja Recomendada: 4083, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: brdc, Cerveja Recomendada: 10672, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: everetends, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: findlayfan, Cerveja Recomendada: 571, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: chaz410, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: TangTKE402, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: nasty15108, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: CHADMC3, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: stonermouse, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: SilentSabre, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: ranger7, Cerveja Recomendada: 221, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: twiggamortis420, Cerveja Recomendada: 29619, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: MattyV, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Jesse13713, Cerveja Recomendada: 48582, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: pezoids, Cerveja Recomendada: 6368, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Maestro, Cerveja Recomendada: 39, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: IrishRedRock, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: goochpunch, Cerveja Recomendada: 712, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: kindacold, Cerveja Recomendada: 47581, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: iuhoosier336, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: nasty15108, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: RoyalT, Cerveja Recomendada: 1005, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: WJVII, Cerveja Recomendada: 28203, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5. 5.]
# Usuário: bennetj17, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: LittleDon, Cerveja Recomendada: 7597, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: koopa, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: sliverX, Cerveja Recomendada: 62891, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: KarlHungus, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: KenC411, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: marc77, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: BierFan, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: germanbeer1, Cerveja Recomendada: 2560, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: augustgarage, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: santoslhalper, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: everetends, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: thartman, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Damian, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: inebrius, Cerveja Recomendada: 224, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: ccrida, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: Brent, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: bewareOFpenguin, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: champ103, Cerveja Recomendada: 62397, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Lukafer, Cerveja Recomendada: 37586, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: 99bottles, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: JohnnyDuvel, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: CrellMoset, Cerveja Recomendada: 51116, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: EagleTalon, Cerveja Recomendada: 12679, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: brentk56, Cerveja Recomendada: 27992, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: atigerlife, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: StonedTrippin, Cerveja Recomendada: 73910, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5. 5.]
# Usuário: UnionMade, Cerveja Recomendada: 934, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: alleykatking, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Blakaeris, Cerveja Recomendada: 19960, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: brew3crew, Cerveja Recomendada: 62172, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: jreitman, Cerveja Recomendada: 4173, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Fnord, Cerveja Recomendada: 48434, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: lordofthewiens, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: chicano4craft, Cerveja Recomendada: 7971, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: NHGrafx, Cerveja Recomendada: 141, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: Nipitato, Cerveja Recomendada: 1708, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: brystmar, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: barleywinefiend, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: JohnnyBarman, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: crazybrody06, Cerveja Recomendada: 576, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mdaschaf, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Liverpool08, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: BierFan, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: HeyItsChili, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: TheodorHerzl, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: bashiba, Cerveja Recomendada: 57747, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: RDHerm, Cerveja Recomendada: 1696, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: SaCkErZ9, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Crosling, Cerveja Recomendada: 7520, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: stoutfiend27, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: spiffysamurai, Cerveja Recomendada: 571, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: TheBungyo, Cerveja Recomendada: 24273, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: gkunkle, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: azorie, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: nickfl, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: david131, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: oberon, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: plaztikjezuz, Cerveja Recomendada: 645, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Vancer, Cerveja Recomendada: 73, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: ejyoung, Cerveja Recomendada: 54745, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: brentk56, Cerveja Recomendada: 27992, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [4.5]
# Usuário: mralphabet, Cerveja Recomendada: 48434, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: marcobrau, Cerveja Recomendada: 132, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Mustard, Cerveja Recomendada: 221, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: cbl2, Cerveja Recomendada: 28203, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: TheJollyHop, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: BEERchitect, Cerveja Recomendada: 1808, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: kinger, Cerveja Recomendada: 1160, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: kindestcut, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: TwinSox33, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jasonjlewis, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: UberWasser, Cerveja Recomendada: 34, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: haywire77, Cerveja Recomendada: 28203, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: atremains, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: halfP1NT, Cerveja Recomendada: 11757, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [4.5]
# Usuário: Sallerj, Cerveja Recomendada: 36333, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: MrDonQuixote, Cerveja Recomendada: 70155, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: imanidiot777, Cerveja Recomendada: 48434, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: JoeyBeerBelly, Cerveja Recomendada: 37586, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.]
# Usuário: wofat, Cerveja Recomendada: 773, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [4.5]
# Usuário: onix1agr, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Brewnami, Cerveja Recomendada: 34, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: timbro81, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: AtLagerHeads, Cerveja Recomendada: 7597, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: mcarroll10177, Cerveja Recomendada: 276, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mikul93, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Slynger, Cerveja Recomendada: 39, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: gregshead, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: saintwarrick, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: DCon, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Tinfoilrcr, Cerveja Recomendada: 1558, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: twiggamortis420, Cerveja Recomendada: 29619, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Hophead101, Cerveja Recomendada: 2751, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: bobsy, Cerveja Recomendada: 6368, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: BeerAngel, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: emmasdad, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Onenote81, Cerveja Recomendada: 44942, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: mjpolzin, Cerveja Recomendada: 28203, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: barleywinebrewer, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mdagnew, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: superbeeje, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Nick3, Cerveja Recomendada: 22790, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: righthereisay, Cerveja Recomendada: 39722, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: merlin48, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: guinness33, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: brewcrew76, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: SykDoc, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: yen157, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Cyberkedi, Cerveja Recomendada: 2093, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5 5.  5.  5. ]
# Usuário: MrMcGibblets, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5 5. ]
# Usuário: womencantsail, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: everetends, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Bitterbill, Cerveja Recomendada: 44942, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Spica66, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: Donnie2112, Cerveja Recomendada: 34420, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: SheepNutz, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: KickbacksSteve, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: evantwomey, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: froghop, Cerveja Recomendada: 695, Nota Máxima: 4.5, Nota Recomendada: 3.5, Erro: 1.0
# [4.5]
# Usuário: shbobdb, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: GoodKnight1220, Cerveja Recomendada: 228, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: tugdriver7, Cerveja Recomendada: 712, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: BayouBengal1537, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: travolta, Cerveja Recomendada: 59, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: Zorro, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: bucklemyshoe, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: alkemy, Cerveja Recomendada: 37192, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Gobzilla, Cerveja Recomendada: 40502, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Dertbert, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: cretemixer, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: RocketWidget, Cerveja Recomendada: 88, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Centennial, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Gritsak, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: paytoplay, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: russpowell, Cerveja Recomendada: 219, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [5.]
# Usuário: prdstmnky, Cerveja Recomendada: 17443, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: rebelthrower, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: perrymarcus, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: dyremohr, Cerveja Recomendada: 11757, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: brewcrew76, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: biboergosum, Cerveja Recomendada: 22227, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: IronCitySteve, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: berserker256, Cerveja Recomendada: 2040, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: haddon, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: DirtybeerguyRI, Cerveja Recomendada: 47905, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: FickleBeast, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: NeroFiddled, Cerveja Recomendada: 28296, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: winomark, Cerveja Recomendada: 1093, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: bjohnson, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: StlHopHead77, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: woodychandler, Cerveja Recomendada: 224, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Dogbrick, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: HopGoblin, Cerveja Recomendada: 358, Nota Máxima: 4.0, Nota Recomendada: 4.0, Erro: 0.0
# [5.]
# Usuário: LordofTime25, Cerveja Recomendada: 9478, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: wl0307, Cerveja Recomendada: 30517, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.]
# Usuário: Gavage, Cerveja Recomendada: 47022, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: AgentZero, Cerveja Recomendada: 61100, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: BigPlay1824, Cerveja Recomendada: 43335, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: OWSLEY069, Cerveja Recomendada: 7520, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Cwrw, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: illinibeerman, Cerveja Recomendada: 279, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: allboutbierge, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: jeffjeff1, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Overlord, Cerveja Recomendada: 26395, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: foXXtail, Cerveja Recomendada: 1093, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: phingdong, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: JayQue, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Erdinger2003, Cerveja Recomendada: 9086, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: KickInTheChalice, Cerveja Recomendada: 34313, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: stephendedalus, Cerveja Recomendada: 44138, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: joeland, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: DrJay, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: dirtylou, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: weeare138, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: tgbljb, Cerveja Recomendada: 9478, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Mavajo, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Foxman, Cerveja Recomendada: 59163, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: lacqueredmouse, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: jmarsh123, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Strix, Cerveja Recomendada: 42084, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Bung, Cerveja Recomendada: 34313, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jzeilinger, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: RyanH, Cerveja Recomendada: 2093, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: zimm421, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: brdc, Cerveja Recomendada: 10672, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: ithacabaron, Cerveja Recomendada: 20518, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: ChimRichels, Cerveja Recomendada: 56738, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Viggo, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: pasdachuri, Cerveja Recomendada: 11757, Nota Máxima: 4.5, Nota Recomendada: 3.5, Erro: 1.0
# [5.]
# Usuário: WeymouthMike, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mothman, Cerveja Recomendada: 38094, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: uustal, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: jameaterblues, Cerveja Recomendada: 34, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Spider889, Cerveja Recomendada: 62397, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: schwaeh, Cerveja Recomendada: 7971, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: Bubba83, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Contagion, Cerveja Recomendada: 927, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Rhettroactive, Cerveja Recomendada: 68548, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: atpben, Cerveja Recomendada: 19960, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [2.5]
# Usuário: JesteR14, Cerveja Recomendada: 1093, Nota Máxima: 5.0, Nota Recomendada: 2.5, Erro: 2.5
# [4.5]
# Usuário: MrHungryMonkey, Cerveja Recomendada: 2093, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: filabrazilia, Cerveja Recomendada: 1558, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: JohnFatAss, Cerveja Recomendada: 54904, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: wl0307, Cerveja Recomendada: 30517, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mtrentm, Cerveja Recomendada: 22790, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: srrn, Cerveja Recomendada: 1708, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: merlin48, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Luigi, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: HardTarget, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: WVbeergeek, Cerveja Recomendada: 222, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: BeanBone, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: MABZ, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: sweemzander, Cerveja Recomendada: 17647, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: WeisGuy, Cerveja Recomendada: 58610, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: GuinnessSmurf, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: goblue3509, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ZimZamZoom, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: WesWes, Cerveja Recomendada: 55063, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: fear025, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: HopsAreOverrated, Cerveja Recomendada: 11757, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Flounder57, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: roodie, Cerveja Recomendada: 46849, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.]
# Usuário: Durge, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: philbertk, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: ElGordo, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: BeerSox, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: ghostwalker, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: craytonic, Cerveja Recomendada: 44112, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: jbro434, Cerveja Recomendada: 1010, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: tar, Cerveja Recomendada: 1005, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.]
# Usuário: mschofield, Cerveja Recomendada: 1708, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: MM3, Cerveja Recomendada: 53730, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: 4thoseabout2bock, Cerveja Recomendada: 15813, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: prsguitarsr4me, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: echoes, Cerveja Recomendada: 39296, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: dyan, Cerveja Recomendada: 47088, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: flagmantho, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: bogus564, Cerveja Recomendada: 1160, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: kmeves, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: MUSHROOMCLOUD, Cerveja Recomendada: 857, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: rfgetz, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: htomsirveaux, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: davexisxrabid, Cerveja Recomendada: 29619, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: rapidsequence, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: katan, Cerveja Recomendada: 59772, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Reagan1984, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: iceball585, Cerveja Recomendada: 59, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: NeutroMan, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: ottovon, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jsbrendle, Cerveja Recomendada: 21690, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: bgreg3, Cerveja Recomendada: 1158, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: oline73, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: angelmonster, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: guinness33, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Onenote81, Cerveja Recomendada: 44942, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: dfried, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Contra, Cerveja Recomendada: 88, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: OldIronLungs, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: heliosphann, Cerveja Recomendada: 28203, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Erish, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: deereless, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: LilMatrix, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: shand, Cerveja Recomendada: 61877, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: ryanonline, Cerveja Recomendada: 808, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: JoeyBeerBelly, Cerveja Recomendada: 37586, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Grundle20, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: NatetheGreat, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: jreitman, Cerveja Recomendada: 4173, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Sean9689, Cerveja Recomendada: 44112, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Pauly2X, Cerveja Recomendada: 37586, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: illidurit, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: number1bum, Cerveja Recomendada: 62172, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mothman, Cerveja Recomendada: 38094, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: philbe311, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: plaid75, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: geexploitation, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: shroompod, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jzeilinger, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.]
# Usuário: RJLarse, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: MrHungryMonkey, Cerveja Recomendada: 2093, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Puddleglum, Cerveja Recomendada: 221, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: CRJMellor, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: praufs01, Cerveja Recomendada: 2751, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: claytong, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: Unhopped, Cerveja Recomendada: 1904, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: wvsabbath, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Reidrover, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: DrunkMcDermott, Cerveja Recomendada: 1558, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: hoppymeal, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Vancer, Cerveja Recomendada: 73, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: prototypic, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Ryan011235, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: specksnreds, Cerveja Recomendada: 1370, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: SteveO1231, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: oglmcdgl, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: guinness33, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: robbyc1, Cerveja Recomendada: 1577, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Oxymoron, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: joecast, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: TheMistler, Cerveja Recomendada: 1010, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: morbiddrumer, Cerveja Recomendada: 1558, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: Damian, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: charlzm, Cerveja Recomendada: 41815, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: CherylM, Cerveja Recomendada: 140, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: cbros, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: nriech, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: UncleJimbo, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: KickbacksSteve, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mustinsmitty, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jsprain1, Cerveja Recomendada: 6368, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: kmpitz2, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Stocean1, Cerveja Recomendada: 49058, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: engagechad, Cerveja Recomendada: 11757, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: morimech, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: julian, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: chakadrum, Cerveja Recomendada: 22227, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: AwYeh, Cerveja Recomendada: 22227, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: TheBishop, Cerveja Recomendada: 131, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: TCgoalie, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: russpowell, Cerveja Recomendada: 219, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: Lemke10, Cerveja Recomendada: 37586, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: Knapp85, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: deanhead, Cerveja Recomendada: 141, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: dionisio, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: RutgersBeerGuy, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mmmbeer, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mwagner1018, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5 5.  5.  5. ]
# Usuário: MrMcGibblets, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: JoeAmerican77, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: AltBock, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mavbrew, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: BeerFMAndy, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Likeburning, Cerveja Recomendada: 1385, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: champ103, Cerveja Recomendada: 62397, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: MJR, Cerveja Recomendada: 6368, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: bbkd3b, Cerveja Recomendada: 41815, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: nastley3, Cerveja Recomendada: 1094, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: woosterbill, Cerveja Recomendada: 68548, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: thickerfreakness, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: FreshHawk, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: falloutsnow, Cerveja Recomendada: 48434, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: WMEugene, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: JoeyBeerBelly, Cerveja Recomendada: 37586, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: WilliamPhilaPa, Cerveja Recomendada: 1093, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: bark, Cerveja Recomendada: 1354, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mikereaser, Cerveja Recomendada: 44749, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ljbrisson, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: Jason, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [3.5]
# Usuário: jrallen34, Cerveja Recomendada: 60554, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: FreshmanPour77, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: StevieW, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: brendan13, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: Jmoore50, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: GoalieRon33, Cerveja Recomendada: 1093, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: TheLongBeachBum, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [4.5]
# Usuário: Illinick, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: codewarrior, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: TastyTaste, Cerveja Recomendada: 8023, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: tjthresh, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: egajdzis, Cerveja Recomendada: 23413, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: marc77, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: DarrinRasberry, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: steelerguy, Cerveja Recomendada: 41121, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [4.5]
# Usuário: BDTyre, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: NCBeernut, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: schoolteacher, Cerveja Recomendada: 5752, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: shroompod, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Troyone, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: benfons, Cerveja Recomendada: 656, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: Longstaff, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ludachris, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: WeisGuy, Cerveja Recomendada: 58610, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5. 5.]
# Usuário: Jwale73, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: prototypic, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Mitchster, Cerveja Recomendada: 198, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: badbeer, Cerveja Recomendada: 24273, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: d4114, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: foureyedgeek, Cerveja Recomendada: 1093, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: MoreThanWine, Cerveja Recomendada: 1160, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: guinness33, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# ...
# [5.]
# Usuário: Brent, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: jeranbrews, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: ccs, Cerveja Recomendada: 3158, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: JayAre46, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: skeetermoses, Cerveja Recomendada: 7879, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: buckeyesox, Cerveja Recomendada: 33127, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: daliandragon, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Drew966, Cerveja Recomendada: 8984, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Dogbrick, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: jminsc76, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: ZAP, Cerveja Recomendada: 19960, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: gmfessen, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5. 5.]
# Usuário: amphion1065, Cerveja Recomendada: 1577, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: ktrillionaire, Cerveja Recomendada: 43456, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: tlazaroff, Cerveja Recomendada: 54522, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: whynot44, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Tballz420, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: nickfl, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: jsanford, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: BrianBoruma, Cerveja Recomendada: 198, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [4.]
# Usuário: steve8robin, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Overlord, Cerveja Recomendada: 26395, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Stigs, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: JM03, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: RblWthACoz, Cerveja Recomendada: 763, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Fux, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mothman, Cerveja Recomendada: 38094, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: lonestar1836, Cerveja Recomendada: 6518, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: matjack85, Cerveja Recomendada: 48582, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: cvfish, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Agold, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: beertunes, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [5.]
# Usuário: m1ked, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: tavernjef, Cerveja Recomendada: 35738, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: mmahut, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ojclark, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mmmbeer, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Metalmonk, Cerveja Recomendada: 857, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: dippy, Cerveja Recomendada: 224, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: sweemzander, Cerveja Recomendada: 17647, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: SPRichard, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: rowew, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: bditty187, Cerveja Recomendada: 57747, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: BamaBeerBuff, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: mostpoetsdo, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Anthony1, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Brianmerrilyn, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Frozensoul327, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: WJVII, Cerveja Recomendada: 28203, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: scruffwhor, Cerveja Recomendada: 29127, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: GCBrewingCo, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mothman, Cerveja Recomendada: 38094, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: KarlHungus, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: jbowers56, Cerveja Recomendada: 857, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: stcules, Cerveja Recomendada: 23413, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: xhuskr, Cerveja Recomendada: 25755, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: UCLABrewN84, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Noxious26, Cerveja Recomendada: 49058, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: boomer31, Cerveja Recomendada: 46849, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: goschool, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Zorro, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: mbudner, Cerveja Recomendada: 8626, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: GregSVT, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: sholland119, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: GCBrewingCo, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Beerandraiderfan, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Wasatch, Cerveja Recomendada: 22790, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Drew966, Cerveja Recomendada: 8984, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: Metalmonk, Cerveja Recomendada: 857, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: jmarsh123, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: danielharper, Cerveja Recomendada: 7520, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: briman, Cerveja Recomendada: 1062, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.]
# Usuário: TheMetalBrew, Cerveja Recomendada: 102, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Bleedingshrimp, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: rvdoorn, Cerveja Recomendada: 68548, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: bigbubba, Cerveja Recomendada: 88, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: schroederm, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: RenoZymurgist, Cerveja Recomendada: 1708, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ADR, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: billyshears, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: DrewSnyc667, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ChugginOil, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: cpanossian, Cerveja Recomendada: 1545, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: jim102864, Cerveja Recomendada: 7520, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: becktone, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Georgiabeer, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Beertroop, Cerveja Recomendada: 31, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: theghost3, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: daliandragon, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: donteatpoop, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: AudioGilz, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: sinstaineddemon, Cerveja Recomendada: 276, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: tmoneyba, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: SwillinBrew, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: haddon, Cerveja Recomendada: 15881, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Lothore, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: Deuane, Cerveja Recomendada: 53267, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [3.5]
# Usuário: ccrida, Cerveja Recomendada: 571, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: ommegangpbr, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: soulfly1492, Cerveja Recomendada: 42533, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [5.]
# Usuário: benmiliron, Cerveja Recomendada: 17226, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: dizknee24, Cerveja Recomendada: 1708, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: pezoids, Cerveja Recomendada: 6368, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: drinkiusmaximus, Cerveja Recomendada: 88, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: AgentMunky, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: vitrael, Cerveja Recomendada: 16074, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [4.5]
# Usuário: Imbiber, Cerveja Recomendada: 88, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: StevenBilodeau, Cerveja Recomendada: 224, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: Biggness, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.5]
# Usuário: bigeyedfish, Cerveja Recomendada: 2093, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [4.5]
# Usuário: zeff80, Cerveja Recomendada: 64228, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: yeahnatenelson, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5 5. ]
# Usuário: sgoodship, Cerveja Recomendada: 226, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: tkarsies, Cerveja Recomendada: 1545, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: istarilord, Cerveja Recomendada: 966, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.5]
# Usuário: SWMeyer4141, Cerveja Recomendada: 1062, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5. 5.]
# Usuário: Jwale73, Cerveja Recomendada: 23030, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: codsmith, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: beagle75, Cerveja Recomendada: 58610, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: bditty187, Cerveja Recomendada: 57747, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: boomer31, Cerveja Recomendada: 46849, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: iadler, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: goblue3509, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: orbitalr0x, Cerveja Recomendada: 20767, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: AlCaponeJunior, Cerveja Recomendada: 19960, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: GoldenVIKE, Cerveja Recomendada: 19960, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: TastyTaste, Cerveja Recomendada: 8023, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: tmoneyba, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.5]
# Usuário: treehugger02010, Cerveja Recomendada: 141, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: Strix, Cerveja Recomendada: 42084, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5 5. ]
# Usuário: womencantsail, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: kenito799, Cerveja Recomendada: 33127, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: lnashsig, Cerveja Recomendada: 67760, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Goliath, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: MbpBugeye, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Khazadum, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: ibbjamin, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: beertunes, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: dyan, Cerveja Recomendada: 47088, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: checkfeet, Cerveja Recomendada: 28877, Nota Máxima: 4.0, Nota Recomendada: 4.0, Erro: 0.0
# [4.5]
# Usuário: jnn4v, Cerveja Recomendada: 62397, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: John, Cerveja Recomendada: 3995, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Prufrock, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: StoneBrewFanatic, Cerveja Recomendada: 48434, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: burnerfinger, Cerveja Recomendada: 276, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: cbutova, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: levifunk, Cerveja Recomendada: 43335, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: DrDemento456, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: GJ40, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: htomsirveaux, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: yunggunn2k1, Cerveja Recomendada: 228, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [5.]
# Usuário: Lacesoutcody, Cerveja Recomendada: 1904, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: trappistlover, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5 4.5 5. ]
# Usuário: Kegatron, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# ERRO MÉDIO: 0.33541666666666664

# %% [markdown]
# UAU, PARA NOSSAS RECOMENDAÇÕES ONDE SABEMOS OS DADOS O MODELO SE SAIU MUITO BEM, EM MÉDIA ELE RECOMENDA CERVEJAS QUE ESTÃO 0.34 DISTANTES DAS MELHORES AVALIADAS POR AQUELE USUÁRIO, MAS AI SURGE A ÚLTIMA PERGUNTA. SERÁ QUE O MODELO CONSEGUE FAZER ISSO PARA QUEM ELE NÃO CONHECE?

# %%
ratings[ratings['review_profilename'] == 'DrDemento456']
# Out:
#        review_profilename beer_beerid  review_overall
# 13068        DrDemento456        1249             2.5
# 14945        DrDemento456       62648             2.5
# 15944        DrDemento456       27857             2.5
# 18979        DrDemento456       22505             1.0
# 41632        DrDemento456        1903             2.0
# ...                   ...         ...             ...
# 676196       DrDemento456        7697             5.0
# 677930       DrDemento456       45591             5.0
# 678207       DrDemento456       26072             5.0
# 678566       DrDemento456        1741             5.0
# 681890       DrDemento456        2560             5.0
#
# [444 rows x 3 columns]

# %%
recomendar('DrDemento456')
# Out:
# 731

# %% [markdown]
# Vamos validar para dados não vistos pelo modelo

# %%
users = df_validacao['review_profilename'].unique()
for u in users:
    cr = recomendar(u)
    nmax = df_validacao[df_validacao['review_profilename'] == u]['review_overall'].max()
    nd = df_validacao.loc[(df_validacao['review_profilename'] == u) & (df_validacao['beer_beerid'] == cr), 'review_overall'].values
    print(nd)

    if len(nd) > 0:  # Verifique se há valores em nd antes de calcular o erro
        error = abs(nmax - nd[0])  # Use nd[0] para obter o valor único
        err.append(error)
        print(f"Usuário: {u}, Cerveja Recomendada: {cr}, Nota Máxima: {nmax}, Nota Recomendada: {nd[0]}, Erro: {error}")
    else:
        print(f"Usuário: {u}, Cerveja Recomendada: {cr}, Nota Máxima: {nmax}, Nenhuma nota encontrada para a cerveja recomendada")

# Calcule o erro médio apenas se houver erros na lista err
if err:
    average_error = sum(err) / len(err)
    print('ERRO MÉDIO:', average_error)
else:
    print('Nenhum erro calculado.')
# Out:
# [5.]
# Usuário: bluejacket74, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: ppoitras, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: ChainGangGuy, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: Phyl21ca, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: francisweizen, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: dgallina, Cerveja Recomendada: 695, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jmdrpi, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: Mosstrooper, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: wagenvolks, Cerveja Recomendada: 45957, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: avalon07, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: axeman9182, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [3.]
# Usuário: northyorksammy, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [5.]
# Usuário: Ego, Cerveja Recomendada: 9478, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: jjayjaye, Cerveja Recomendada: 45957, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: BuckeyeNation, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.]
# Usuário: mcallister, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [5.]
# Usuário: BigRedN, Cerveja Recomendada: 276, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: GordonQuid, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Globetrotter, Cerveja Recomendada: 731, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: blackie, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: wschmit, Cerveja Recomendada: 62397, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: proc, Cerveja Recomendada: 17112, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: AlexJ, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Florida9, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: pzrhsau, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: kzoobrew, Cerveja Recomendada: 16814, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: MaltyGoodness, Cerveja Recomendada: 22173, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [2.]
# Usuário: jctribe25, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 2.0, Erro: 3.0
# [4.5]
# Usuário: WanderingFool, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: CuriousMonk, Cerveja Recomendada: 56082, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: LordAdmNelson, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: metter98, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: FightingEntropy, Cerveja Recomendada: 28165, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: CHickman, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [5.]
# Usuário: whartontallboy, Cerveja Recomendada: 63649, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: zhanson88, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [5.]
# Usuário: andrenaline, Cerveja Recomendada: 34420, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# [4.5]
# Usuário: Monkeyknife, Cerveja Recomendada: 47658, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.5]
# Usuário: PhxHorn, Cerveja Recomendada: 1545, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [4.]
# Usuário: Mardukk, Cerveja Recomendada: 1010, Nota Máxima: 5.0, Nota Recomendada: 4.0, Erro: 1.0
# [3.]
# Usuário: Mryup, Cerveja Recomendada: 132, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: bnuttz, Cerveja Recomendada: 9478, Nota Máxima: 5.0, Nota Recomendada: 4.5, Erro: 0.5
# [3.]
# Usuário: Mark, Cerveja Recomendada: 21690, Nota Máxima: 5.0, Nota Recomendada: 3.0, Erro: 2.0
# [4.5]
# Usuário: alldaydrinker, Cerveja Recomendada: 857, Nota Máxima: 4.5, Nota Recomendada: 4.5, Erro: 0.0
# [4.]
# Usuário: cgmees, Cerveja Recomendada: 35625, Nota Máxima: 4.5, Nota Recomendada: 4.0, Erro: 0.5
# [3.5]
# Usuário: Kyle987, Cerveja Recomendada: 386, Nota Máxima: 4.5, Nota Recomendada: 3.5, Erro: 1.0
# [3.5]
# Usuário: HalenRush, Cerveja Recomendada: 248, Nota Máxima: 5.0, Nota Recomendada: 3.5, Erro: 1.5
# [5.]
# Usuário: jamesm7485, Cerveja Recomendada: 7971, Nota Máxima: 5.0, Nota Recomendada: 5.0, Erro: 0.0
# ERRO MÉDIO: 0.3405448717948718

# %% [markdown]
# UAU, APÓS SEPARARMOS ALGUNS DADOS PARA VALIDAÇÃO, VEMOS QUE MESMO PARA DADOS QUE O MODELO NUNCA VIU ELE SE SAIU BEM. CONSEGUINDO ENTÃO GENERALIZAR.

# %% [markdown]
# AGORA VAMOS DEIXAR O SISTEMA RECOMENDAR CERVEJAS QUE NÃO SÃO CONHECIDAS POR AQUELE USUÁRIO

# %%
beers_id = df['beer_beerid']
def recomendar(user):
    notas = []
    cervejas = []

    for b in beers_id:
        pred = svd.predict(user, b)
        nota = pred.est
        cerveja_id = pred.iid
        notas.append(nota)
        cervejas.append(cerveja_id)

    indice_max_nota = notas.index(max(notas))
    cerveja_recomendada = cervejas[indice_max_nota]

    return cerveja_recomendada

# %% [markdown]
# temos então a função de recomendação pronta

# %%
#Se optarmos por agrupar estilos de cerveja em categorias similares com base em suas características, realizando uma pesquisa descritiva e categorizada.

# %%
beer_styles = {
    "Ales": [
        "English Strong Ale",
        "English Bitter",
        "English Pale Ale",
        "English India Pale Ale (IPA)",
        "English Brown Ale",
        "English Barleywine",
        "English Dark Mild Ale",
        "Extra Special / Strong Bitter (ESB)",
        "Scottish Ale",
        "Scotch Ale / Wee Heavy",
        "American Strong Ale",
        "American Double / Imperial Stout",
        "American Barleywine",
        "Pumpkin Ale",
        "Altbier",
        "Kölsch",
        "Milk / Sweet Stout",
        "Witbier",
        "Flanders Oud Bruin",
        "American Brown Ale",
        "Winter Warmer",
        "Bière de Garde",
        "English Stout",
        "Scottish Gruit / Ancient Herbed Ale",
        "American Dark Wheat Ale",
        "Old Ale",
        "Quadrupel"
    ],
    "Pale Lagers": [
        "German Pilsener",
        "American Pale Lager",
        "Euro Pale Lager",
        "Maibock / Helles Bock",
        "Czech Pilsener",
        "American Double / Imperial Pilsner"
    ],
    "Dark Lagers": [
        "Munich Dunkel Lager",
        "Schwarzbier",
        "Vienna Lager",
        "Euro Dark Lager",
        "Doppelbock",
        "American Amber / Red Lager",
        "Baltic Porter"
    ],
    "Wheat Beers": [
        "Hefeweizen",
        "Dunkelweizen",
        "Weizenbock",
        "American Pale Wheat Ale",
        "Kristalweizen"
    ],
    "Dark Ales": [
        "Foreign / Export Stout",
        "Oatmeal Stout",
        "American Stout",
        "American Porter",
        "English Porter",
        "Russian Imperial Stout"
    ],
    "Belgian Ales": [
        "Belgian Pale Ale",
        "Belgian Strong Pale Ale",
        "Belgian IPA",
        "Belgian Dark Ale",
        "Dubbel",
        "Tripel",
        "Quadrupel (Quad)",
        "Flanders Red Ale"
    ],
    "IPA and Pale Ales": [
        "American Pale Ale (APA)",
        "American IPA",
        "American Double / Imperial IPA",
        "American Black Ale",
        "American Amber / Red Ale",
        "English Pale Mild Ale"
    ],
    "Specialty Ales": [
        "Fruit / Vegetable Beer",
        "Herbed / Spiced Beer",
        "Belgian Strong Dark Ale",
        "Saison / Farmhouse Ale",
        "American Wild Ale"
    ],
    "Hybrid Styles": [
        "California Common / Steam Beer",
        "Rye Beer",
        "Wheatwine",
        "Black & Tan",
        "Cream Ale"
    ],
    "Special Lagers": [
        "Märzen / Oktoberfest",
        "Rauchbier",
        "Dortmunder / Export Lager",
        "Munich Helles Lager",
        "Doppelbock",
        "Bock",
        "Kellerbier / Zwickelbier"
    ],
    "Unique Styles": [
        "Lambic - Fruit",
        "Lambic - Unblended",
        "Gueuze",
        "Faro",
        "Berliner Weissbier",
        "Gose"
    ],
    "Historical and Uncommon Styles": [
        "Eisbock",
        "Sahti",
        "Kvass",
        "Happoshu",
        "Bière de Champagne / Bière Brut",
        "Roggenbier",
        "Braggot",
        "Smoked Beer"
    ],
    "Light and Low Alcohol Styles": [
        "Light Lager",
        "Low Alcohol Beer",
        "Cream Ale"
    ],
    "Regional Styles": [
        "Irish Dry Stout",
        "Irish Red Ale",
        "American Adjunct Lager",
        "American Blonde Ale",
        "American Malt Liquor",
        "Japanese Rice Lager",
        "Chile Beer"
    ]
}

inverted_beer_styles = {}
for category, styles in beer_styles.items():
    for style in styles:
        inverted_beer_styles[style] = category

# %%
filtered_dem = dem[dem['beer_beerid'] == 731]
metch = filtered_dem['beer_style'].to_string(index=False)

# %%
style_to_metch = "American IPA"
if style_to_metch in inverted_beer_styles:
    category = inverted_beer_styles[style_to_metch]
    print(f"O estilo de cerveja '{style_to_metch}' pertence à família '{category}'.")
else:
    print(f"O estilo de cerveja '{style_to_metch}' não foi encontrado.")
# Out:
# O estilo de cerveja 'American IPA' pertence à família 'IPA and Pale Ales'.

# %%
#Se desejarmos oferecer uma recomendação para um estilo de cerveja, uma cerveja brasileira com características semelhantes

# %%
beers_dict = {
    "Ale" : "Colorado Appia",
    "Pale lager": "Paulistânia Marco Zero",
    "Dark lager": "Baden Baden Bock",
    "Wheat Beers": "Baden Baden Weiss",
    "Dark Ale": "Cacau Wee",
    "Belgian Ales": "Blanche de Curitiba",
    "IPA and Pale Ales": "Session Citra",
    "Specialty Ales": "Labareda - Cervejaria Júpiter",
    "Hybrid Style": "Bodebrown Cacau IPA",
    "Special Lagers": "Bamberg Camila Camila",
    "Unique Style": "Amburana Lager",
    "Historical and Uncommon Styles": "Catharina Sour",
    "Light and Low Alcohol Styles": "Session IPA",
    "Regional Styles": "Wäls Trippel"
}

# %%
print(category)
style_to_metch = category
if style_to_metch in beers_dict:
    category = beers_dict[style_to_metch]
    print(f"Para a família de cerveja '{style_to_metch}' recomendamos a brasileira '{category}'.")
else:
    print(f"Para a família de cerveja '{style_to_metch}' não recomendamos nada :-(.")
# Out:
# IPA and Pale Ales
# Para a família de cerveja 'IPA and Pale Ales' recomendamos a brasileira 'Session Citra'.
